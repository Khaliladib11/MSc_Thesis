# %% [markdown]
# # BDD Detection Class

# %% [markdown]
# ## Import Libraries

# %%
from config.defaults import cfg
from dataset.bdd_detetcion import BDD_Detection
import random

# %% [markdown]
# ## Initialize Dataset Class

# %%
# %%time
bdd_params = {
    'cfg': cfg,
    'stage': 'train'
}

bdd_class = BDD_Detection(**bdd_params)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 69863/69863 [00:06<00:00, 10342.77it/s]
# CPU times: total: 25.8 s
# Wall time: 26.9 s

# %% [markdown]
# ## Display Random Image

# %%
idx = random.randint(0, len(bdd_class))
bdd_class.display_image(idx)
