# %% [markdown]
# # BDD Detection Class

# %% [markdown]
# ## Import Libraries

# %%
from config.defaults import cfg
from dataset.bdd_detetcion import BDDDetection
import random

# %% [markdown]
# ## Initialize Dataset Class

# %%
obj_cls = ['__bgr__', 'pedestrian', 'rider', 'car', 'bus', 'motorcycle', 'bicycle', 'traffic light']

# %%
# %%time
bdd_train_params = {
    'cfg': cfg,
    'stage': 'train',
    'obj_cls': obj_cls
}

bdd_train = BDDDetection(**bdd_train_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 69863/69863 [00:08<00:00, 7981.27it/s]
# CPU times: total: 30.7 s
# Wall time: 32.4 s

# %%
# %%time
bdd_val_params = {
    'cfg': cfg,
    'stage': 'val',
    'obj_cls': obj_cls
}

bdd_val = BDDDetection(**bdd_val_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 69863/69863 [00:07<00:00, 9843.69it/s]
# CPU times: total: 27.5 s
# Wall time: 28.9 s

# %%
# %%time
bdd_test_params = {
    'cfg': cfg,
    'stage': 'test',
    'obj_cls': obj_cls
}

bdd_test = BDDDetection(**bdd_test_params)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 12006.08it/s]
# CPU times: total: 5.64 s
# Wall time: 6.98 s

# %%
print(f"We have {len(bdd_train)} training image, {len(bdd_val)} validation images and {len(bdd_test)} test images.")
# Out:
# We have 55615 training image, 13904 validation images and 9956 test images.

# %% [markdown]
# ## Display Random Image

# %%
idx = random.randint(0, len(bdd_train))
bdd_train.display_image(idx)

# %%
idx = random.randint(0, len(bdd_val))
bdd_val.display_image(idx)

# %%
idx = random.randint(0, len(bdd_test))
bdd_test.display_image(idx)

# %% [markdown]
# ## Exporting DBs

# %%
bdd_train.export_db('./dbs')
bdd_val.export_db('./dbs')
bdd_test.export_db('./dbs')
# Out:
# Exporting train_db DB...
# DB train_db Exported.
# Exporting val_db DB...
# DB val_db Exported.
# Exporting test_db DB...
# DB test_db Exported.
