# %% [markdown]
# # BDD Detection Class

# %% [markdown]
# ## Import Libraries

# %%
from config.defaults import cfg
from dataset.bdd_detetcion import BDDDetection
import random

# %% [markdown]
# ## Initialize Dataset Class

# %%
obj_cls = ['__bgr__', 'pedestrian', 'car', 'rider', 'bicycle', 'motorcycle', 'truck', 'bus']

# %%
# %%time
bdd_train_params = {
    'cfg': cfg,
    'stage': 'train',
    'obj_cls': obj_cls
}

bdd_train = BDDDetection(**bdd_train_params)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 69863/69863 [00:07<00:00, 9486.01it/s]
# CPU times: total: 30.4 s
# Wall time: 31.5 s

# %%
# %%time
bdd_val_params = {
    'cfg': cfg,
    'stage': 'val',
    'obj_cls': obj_cls
}

bdd_val = BDDDetection(**bdd_val_params)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 69863/69863 [00:06<00:00, 11533.89it/s]
# CPU times: total: 25.6 s
# Wall time: 28.3 s

# %%
# %%time
bdd_test_params = {
    'cfg': cfg,
    'stage': 'test',
    'obj_cls': obj_cls
}

bdd_test = BDDDetection(**bdd_test_params)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 32234.39it/s]
# CPU times: total: 3.59 s
# Wall time: 4.24 s

# %%
print(f"We have {len(bdd_train)} training image, {len(bdd_val)} validation images and {len(bdd_test)} test images.")
# Out:
# We have 55422 training image, 13856 validation images and 9919 test images.

# %% [markdown]
# ## Display Random Image

# %%
idx = random.randint(0, len(bdd_train))
bdd_train.display_image(idx)

# %%
idx = random.randint(0, len(bdd_val))
bdd_val.display_image(idx)

# %%
idx = random.randint(0, len(bdd_test))
bdd_test.display_image(idx)

# %% [markdown]
# ## Exporting DBs

# %%
bdd_train.export_db('./dbs')
bdd_val.export_db('./dbs')
bdd_test.export_db('./dbs')
# Out:
# Exporting train_db DB...
# DB train_db Exported.
# Exporting val_db DB...
# DB val_db Exported.
# Exporting test_db DB...
# DB test_db Exported.
